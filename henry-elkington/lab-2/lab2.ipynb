# %%
import torch
import torchaudio

# Load the audio file
waveform, sample_rate = torchaudio.load("sound.wav")

print(f"Waveform shape: {waveform.shape}")
print(f"Sample rate: {sample_rate}")
print(f"Duration: {waveform.shape[1] / sample_rate:.2f} seconds")
print(f"Channels: {waveform.shape[0]}")
# Out:
# Waveform shape: torch.Size([2, 499996])
# Sample rate: 44100
# Duration: 11.34 seconds
# Channels: 2
