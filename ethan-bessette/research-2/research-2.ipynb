# %% [markdown]
# First, we have to log in to Hugging Face to download the pre-trained weights. If you haven't already, make an account [here](huggingface.co). Then, naviagte the settings page, access tokens, and create a token.

# %%
hf auth login
# Out:
#   Cell In[1], line 1
#     hf auth login
#        ^
# SyntaxError: invalid syntax
