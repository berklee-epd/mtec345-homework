# %%
import torch
import torchaudio

# Load the audio file
waveform, sample_rate = torchaudio.load("your-audio-file.wav")

print(f"Waveform shape: {waveform.shape}")
print(f"Sample rate: {sample_rate}")
print(f"Duration: {waveform.shape[1] / sample_rate:.2f} seconds")
print(f"Channels: {waveform.shape[0]}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 5
#       2 import torchaudio
#       4 # Load the audio file
# ----> 5 waveform, sample_rate = torchaudio.load("your-audio-file.wav")
#       7 print(f"Waveform shape: {waveform.shape}")
#       8 print(f"Sample rate: {sample_rate}")
#
# File ~/Documents/GitHub/mtec345-homework/david-wauters/lab-2/.venv/lib/python3.13/site-packages/torchaudio/__init__.py:86, in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#      18 def load(
#      19     uri: Union[BinaryIO, str, os.PathLike],
#      20     frame_offset: int = 0,
#    (...)     26     backend: Optional[str] = None,
#      27 ) -> Tuple[torch.Tensor, int]:
#      28     """Load audio data from source using TorchCodec's AudioDecoder.
#      29
#      30     .. note::
#    (...)     84         by TorchCodec.
# ...
